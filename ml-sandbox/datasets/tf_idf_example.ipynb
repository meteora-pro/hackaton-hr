# %%
import pandas as pd
import wikipedia


articles=["JavaScript","PHP","MySQL","PostgreSQL","Linux","SQL","ООП","HTML","CSS","Java","Python","Node.js","HTML5","jQuery","CSS3","C#","MongoDB","REST","Redis","React","Spring Framework","Docker","Английский язык","Atlassian Jira","1С-Битрикс","Laravel","Symfony","Yii","PHP5","Django Framework","Android","Работа в команде","Ajax","Bootstrap","AngularJS","ASP.NET","Scrum","TypeScript","MVC","MS SQL","Golang",".NET Framework","Agile Project Management","Nginx","API","Kotlin","iOS","XML","RabbitMQ","Веб-программирование","Design Patterns","Управление проектами","Hibernate ORM","Android SDK","Ruby","C++","Java SE","Ruby On Rails","PHP7","Entity Framework","Функциональное тестирование","Elasticsearch","Less","Sass","Kubernetes","SOAP","Angular","Тестирование","Yii2","Backend","Базы данных","react","Vue.js","Go","HTTP","JSON API","NoSQL","laravel","Java EE","CMS Wordpress","MS SQL Server","QA","Vue","Управление командой","Apache Maven","SCALA","Atlassian Confluence","Разработка технических заданий","Redux","Adobe Photoshop","ORACLE","Разработка ПО","Креативность","Teamleading","Gulp","JUnit","Unit Testing","Spring","React.js","Swift","Тестирование пользовательского интерфейса","Пользователь ПК","JSON","Bitrix","docker","ReactJS",".NET Core","ClickHouse","Mac Os","typescript","SEO","Objective-C","Bash","kotlin","MS Visual Studio","Apache Tomcat","Unix","Cистемы управления базами данных","Веб-аналитика","Kanban","Верстка","Мобильность","Разработка нового продукта","Joomla CMS","Управление рисками","Webpack","Frontend","BPM","Битрикс","UX","Transact-SQL","AWS","Работа с базами данных","Figma","clickhouse","Typescript","СУБД","ORM","Rspec","vue.js","Регресcионное тестирование","Бизнес-анализ","Jenkins","WPF","ASP.NET MVC","CI/CD","Test case","Аналитическое мышление","Magento","React Native","Bitrix framework","Битрикс24","WEB","Kafka","Flask","Elixir","Zend Framework","REST API","CRM","Memcached","Oracle Pl/SQL","golang","Управление временем","SOLID","backend","Ведение переговоров","TCP/IP","Кроссбраузерная верстка","Web-дизайн","Веб-дизайн","UI","Системный анализ","T-SQL","Проведение тестирований","Web Application Development","Информационные технологии","Ansible","MS Project","Нагрузочное тестирование","UML","GitLab","react.js","WCF","Clickhouse","JS","Администрирование серверов Linux","База данных: Oracle","руководство командой разработчиков","vue","Коммуникабельность","Руководство коллективом","Jira","prebid.js","Selenium IDE","Data Mining","Аналитика","Java Servlets","MS PowerPoint","WebSocket","Системная интеграция",".NET","Создание сайтов","TDD","Google Analytics","Product Management","Умение работать в команде","Анализ данных","Nuxt","LINQ","Celery","Grafana","Управление разработкой","Project management","Jetbrains Phpstorm","Регресионное тестирование","BPMN","SQLite","Постановка задач разработчикам","Code review","Gitlab","webpack","Apache HTTP Server","Pascal","SQL Server","VueJS","redux","Ориентация на результат","CMS","JSP","Грамотная речь","Lumen","Интернет-реклама","Запуск новых продуктов","EVO CMS","Youtrack","TFS","Internet Marketing","Яндекс.Метрика","Маркетинговый анализ","Обратная связь","Системность","Написание качественных и понятных ТЗ","Blockchain","Software Development","JPA","C/C++","Битрикс 24","PSR","SVN","Visual Studio C#","Документооборот","Spring Boot","Drupal API","Windows 7","WEB аналитика","NET Core / ASP.NET Core / .NET Framework","• C#","Intellij IDEA","Highload","Microservices","Web Design","Деловая коммуникация","Azure","GraphQL","Управление интернет-проектами","Управление процессами","NHibernate","Confluence","Планирование","Аналитический склад ума","Selenium","Back-end","Vue JS","1С: Управление Торговлей","Leaflet","Ответственность","PHP 7","Управление персоналом","php7","ERP","phpMyAdmin","Алгоритмы","TeamCity","Express.js","google admanager","Google AdManager","Урегулирование конфликтов","Bitrix 24","PHP modules","Hibernate","Graylog","Автоматизация","Проектный менеджмент","Моделирование бизнес процессов","Бизнес-моделирование","ABC-анализ","KPI","Проведение рекламных кампаний","1С программирование",".net core","RTMP","Erlang","allure","py.test",".Net Core","Проектирование пользовательских интерфейсов","Внутренние коммуникации","Slack","Agile","Solid Edge","modx","Angular2","Многозадачность","UIKit","ActiveMQ","Leadership Skills","Mobx","Backbone","Windows Forms","Обучение и развитие","SCSS","yii2","Websockets","NodeJS","Vue js","Разработка CMS","nuxt","Гибкость","Работа с людьми","PHPUnit","Debian","Асинхронное программирование","Расстановка приоритетов","Junior","Разработка сайтов","Сбор и анализ информации","RxJS","• Написание тестов","• MS SQLServer","Web API (REST/RESTful)","Angular / React / Vue / Svelte / Blazor","• JS / TypeScript / HTML / CSS","• Entity Framework или аналоги","BEM","MS Access","Планирование карьеры","Xsd","Ручное тестирование","swift","Databases","Machine Learning","Адаптивная верстка","Zabbix","Crystal","SPA","Оптимизация бизнес-процессов","Техническая документация","VUE","Системное администрирование","Pytest","Big Data","Xamarin","Xcode","aiohttp","Gitflow","TestNG","C#/.NET","WebSockets","moodle","Shop Script","MODx","Redmine","SSR","Protobuf","GRPC","ASP.NET Core","SaaS","DRF","WebApi","GoLang","Django","GO","Mercurial","Ubuntu","MariaDB","CentOS","YouTrack","spring boot","NestJS","Инициативность","DRY","Организаторские навыки","Git","Data Analysis","Математическая статистика","B2B Продажи","MS Excel","Холодные продажи","Активные продажи","ETL","Деловая переписка","MATLAB","Клиентоориентированность","AllFusion ERwin Data Modeler","Телефонные переговоры","Контекстная реклама","Деловое общение","Навыки продаж","Поиск и привлечение клиентов","Power BI","Аналитические исследования","Выездное обслуживание","Google AdWords","Математический анализ","Статистический анализ","Техническое обслуживание","Настройка ПК","Digital Marketing","Time management","PowerShell","Active Directory","Windows Os","Навыки презентации","Работа с большим объемом информации","Business English","TensorFlow","PyTorch","MS Visio","Математическое моделирование","Управление отношениями с клиентами","Настройка сетевых подключений","Развитие продаж","Подготовка коммерческих предложений","Грамотность","Настройка ПО","Корпоративные продажи","Яндекс.Директ","Администрирование серверов Windows","Business Development","Data Science","DWH","Tableau","Сборка ПК","Монтаж оборудования","Прямые продажи","Составление договоров","Helpdesk","Eclipse","Таргетинг","Presentation skills","Negotiation skills","Marketing Analysis","Analytical skills","Spark","Business Intelligence Systems","MS Office","GPON","Системное мышление","VBA","MS Outlook","Проведение презентаций","R","Computer Vision","Анализ бизнес процессов","Google Sheets","Заключение договоров","Навыки переговоров","Инженерные системы","SCCM","PowerBI","Ремонт ПК","Windows Xp","Прокладка кабелей","Мотивация","Ориентация на клиента","Поиск информации в интернет","Cisco","VoIP","Офисная техника","ITSM","Hadoop","Phyton","Rx","Техническая поддержка","Customer Support","Стрессоустойчивость","Обучение","Oracle Database","Olap (online analytical processing)","Управление продуктом","NLP","Mathcad","Greenplum","MS Visual Basic","Time Series Analysis","Natural Language Processing","DAX","1С: Предприятие 8","Управление продажами","WMS","MS Dos","Контроль дебиторской задолженности","Контроль качества","SMM","DHCP","Настройка DNS","Spring Data","Borland C++","Информационная безопасность","КХД","Статистика","B2C продажи","Администрирование","Развитие ключевых клиентов","Анализ конкурентной среды","1С: Документооборот","опыт работы аналитиком","взаимодействие с заказчиками","Social Media Marketing","Qt","Postgres","Программирование мобильных приложений","Разработка мобильных приложений","Yandex Direct","Медиапланирование","E-Mail Marketing","Управление бюджетом","Maven","Teamplayer","Sales Management","Оценка потребностей клиентов","Работа с ключевыми клиентами","nocode","Hyper-V","Windows Server","Perl","devops","Google Docs","Shell Scripting","Gradle","Customer Service","Стратегическое мышление","Sales Skills","Тайм-менеджмент","Cassandra","Algorithms and Data Structures","Written Translation","Team management","Shell\\Perl скрипты","Data Engineering","Elastic Search","Account Management","Market Research","Планирование продаж","Windows 8","Teambuilding","Networking","Проектная документация","BI","Прогнозирование","Adobe Illustrator","Графический дизайн","Копирайтинг","CorelDRAW","Дизайн","Интернет маркетинг","Продвижение бренда","Дизайн интерфейсов","Ведение групп в социальных сетях","Наполнение контентом","SEO оптимизация","Маркетинговые коммуникации","Продажи через интернет","Разработка маркетинговой стратегии","Социальные сети","Лидогенерация","Unity","Работа с клиентами","Холодные звонки","Консультативные продажи","телефонные продажи","исходящие звонки","Аналитика продаж","входящие звонки","Adobe InDesign","Навыки работы с возражениями","Телемаркетинг","Продвижение сайтов","Altium Designer","Написание текстов","Администрирование сайтов","AutoCAD","Графические редакторы","Прототипирование","Usability","Adobe After Effect","Планирование маркетинговых кампаний","Написание статей","3D Моделирование","Составление семантического ядра","Разработка концепции","B2B маркетинг","3ds Max","Графика","Маркетинговое планирование","Маркетинговые исследования","Схемотехника электронного оборудования","SMO","E-Commerce","Творческое мышление","Стратегический маркетинг","Подготовка презентаций","Планирование рекламных кампаний","Внешняя оптимизация сайта","Формирование технического задания для разработки","Реклама","Фотография","Email маркетинг","Обработка изображений","B2C маркетинг","Видеомонтаж","Поисковая оптимизация сайтов","PR","внешний аудит сайта","SolidWorks","Художник","Иллюстрирование","P-CAD","Написание рекламных статей","Аудит поисковой видимости сайта","Рисунок","Анимация","figma","Маркетинг услуг","Анализ посещаемости сайтов","Баннерная реклама","ЕСКД","SEO-копирайтинг","внутренний аудит сайта","SketchUp","САПР","Разработка проектной документации","Корректура текстов","Редактирование текстов","Маркетинг","Живопись","Веб-разработка","Дистанционное обучение","Умение работать в коллективе","Продвижение в социальных группах","Аудит SMM","Внутренняя оптимизация сайта","Разработка регламентов","Компас-3D","Сопровождение клиентов","Дизайн полиграфии","Обучаемость","Обработка видео","Навыки межличностного общения","Бюджетирование","Разработка инструкций","Рерайтинг","Поисковые системы","Внутренний аудит контекстной рекламы","Cоциальная реклама","3D Max","3D-графика","Autodesk 3ds Max","Adobe Lightroom","Видеосъемка","Проектирование","Sketch","Adobe Flash","Ведение документации","IDEF","Поисковая оптимизация мобильной версии сайта","Участие в профессиональных выставках","Проектно-конструкторская деятельность","Администрирование сетевого оборудования","Анализ рынка","ZBrush","Cоциальный маркетинг","Исполнение личных поручений руководителя","исполнение поручений руководителя","Прием и распределение звонков","Развитие бренда","Adobe Dreamweaver","Разработка фирменного стиля","Axure RP","Adobe Premier Pro","Дизайн интерьера","Работа с возражениями","Анализ трафика","CPA","Управление лояльностью потребителей","Управление производством","Обучение персонала","Tilda","Бизнес-планирование","Медиабаинг","Ведение активных клиентов","оптимизация рекламных кампаний","Умение планировать","Автоматизация контекстных кампаний","Продвижение объекта","Adobe Premier","Организационные навыки","Интервьюирование","Информационные рассылки","Внешний аудит контекстной рекламы","SMS маркетинг","Анализ бизнес показателей","1С: Зарплата и управление персоналом","Adobe Design","Редактирование","VMware","CorelDRAW Photo Draw","Autodesk Maya","Internet","game design","Adobe XD","Внимательность","Ведение клиентской базы","Работа со СМИ","Adobe Acrobat","Проведение переговоров","План продвижения","Высокая скорость печати","Speed paint","Ведение отчетности","Мотивация персонала","Наружная реклама","Организация мероприятий","Facebook","Аналитические способности","Design Thinking","Анализ продаж","Документальное сопровождение","Google Ads","Advertising","1С: Торговля","разработка чертежей","Журналистика","Flutter","Windows","1С: Бухгалтерия","CorelDRAW Graphics Suite","Проектирование интерфейсов","Фотомонтаж","Разработка компьютерных Игр","Sony Vegas","UI/UX","Самоорганизация","Чувство вкуса","Партнерские программы в социальных сетях","Net Core","OpenGL","Продвижение мероприятий компании в социальных сетях","Вывод продукта на рынок","STM32","Усидчивость","Управление производственным персоналом","ГОСТ","SPI","ARM","B2C Marketing","instagram","Windows Server 2003","IDEF0","Microsoft Dynamics AX","Умение принимать решения","Visual Basic","Организация промо акций","STL","Facebook Ads","Управленческие навыки","ES6","Технический контроль производства","B2B Marketing","Подбор персонала","GitLab CI","Мониторинг цен","Электронная почта","Консультирование","Scss","scss","Solid Works","Студийная фотосъемка","Предметная фотосъемка","Консультирование клиентов","CJM","Дизайн мобильных приложений","UI, UX design","Интерактивный дизайн","Адаптивный дизайн","Стратегическое планирование","PMBOK","Adobe CS","Конкурентная аналитика","Написание процедур","TMS Systems","Производство рекламных материалов","Instagram","web-разработка","Станки ЧПУ","Разработка продукта","1C: Бухгалтерия","Cinema 4D","Black box testing","адаптивная верстка","2D","Paint Tool SAI","Внутренний контроль","UX/UI","VFX","Полиграфический дизайн","гейм-дизайн","Design","Zeplin","Оптико-механические устройства","Технический перевод","Управление маркетингом","ADO.NET","программирование","ERP Systems","SAP ERP","медийная реклама","WebGL","Secuity Software","Оптовые продажи","таргетированная реклама","ROI","ReactNative","Поисковая оптимизация мобильного приложения","Менеджмент","mobx","Собеседование","Повышение конверсии","Modbus","Навыки телефонных продаж","BTL","ATL","MSP430","ZigBee","I2C","Ethernet","Salesforce","Электронный документооборот","производство","Google","Настройка трекеров","Бодрость духа","Настойчивость","Адекватность","Целеустремленность","Spine","Media Buying","ERP-системы на базе 1С","Launching new products","Вконтакте","Google Cloud","Табличная верстка","Семантическая верстка","Блочная верстка","Запуск федеральных рекламных кампаний","1С: Предприятие","Ansi C++","Ведение переписки","Работа с документами","KiCAD","SWOT анализ","Проведение промо акций","Adobe Audition","Настройка почтовых серверов","Контроль оформления документов","Визуальный мерчандайзинг","Анализ PR стратегии конкурентов","Beta-тестирования","Проведение опросов","1С: Управление предприятием","Product Development","Опыт продаж","маркетинг","Французский язык","FPGA","Оценка персонала","Навигационные сайты","Microsoft Visual Studio","Умение расставлять приоритеты","Здоровая амбициозность","Умение смотреть на мир шире","Желание общаться в команде с интересными людьми","Ответственность за результат","Внимательность к деталям","Любовь к искусству","Чтение чертежей","3D","Miro","Corel Draw","Вывод компании на рынок","Скетч","Запуск региональных рекламных кампаний","Driving Licence B","Bug Reporting","оформление документации","интернет-проекты","Pug","Project Documentation","Программирование микроконтроллеров","Content Strategy","Content Plan","Marketing Communication","Unreal Engine","Firebase","RxJava","Первичная бухгалтерская документация","1C: Зарплата и кадры","Расчет заработной платы","Налоговая отчетность","Бухгалтерская отчетность","Портретная фотосъемка","Интерьерная фотография","Лидерские качества","Исследования рынка","Trade Marketing","UX-тест","JTBD","Customer Development","декомпозировать решения","CustDev","прототип","flutter","C++11","Написание научный статей","мобильные разработки","OOP","OOD","Системный подход","Vue.JS","web разработка","PostCSS","ES6+","Интеграционное тестирование","Пунктуальность","MS Word","V-Ray","Визуализация","Мерчандайзинг","Web-development","концептуальный дизайн","Анализ ассортиментной линейки","Создание систем перелинковок","MSSQL","frontend","Точность и внимательность к деталям","Литературное редактирование","С#","HDL","ПЛИС","Чтение электросхем","Редакторская деятельность","Написание пресс-релизов","Prometheus","Dart","Cadence","Цифровая схемотехника","Аналоговая схемотехника","QML","Pinnacle Studio","Animation","Blender 3D","gamedev","compiler","Bug Tracking Systems","Maya","Управление талантами","f2p","Illustrator","style guide","ScetchUp","UI design","Мобильные приложения","Рисунок от руки","Исполнительность","Adobe After Effects","game","Game Programming","sketch","Способность обучать других","DevOps","Terraform","kubernetes","Ubuntu Server","Devops","Puppet","VPN","Pipeline","Tarantool","ITIL","Microsoft Azure","IIS","Mikrotik","MS Publisher","FreeBSD","OpenVPN","Bitbucket","Proxmox","«PHP», «JavaScript», «MySQL», «Git», «HTML», «jQuery», «ООП», «CSS», «PHP5», «1С-Битрикс», «CSS3», «","OpenCV","Websocket","Delphi","Рекрутмент","Unix Shell Scripts","EFK","k8s","OpenShift","ELK","Микросервисы","ДБО","Helm","SLA","Apache","KVM","С","OpenStack","SSL/TLS","ESXi","Cloud","ansible","Lavarel","Babel","Vuex","Jest","vuex","VueJs","Canvas","enzyme","vuejs","VUE.JS","Ext JS","БЭМ","Nuxt.js","ReactJs","SIP","Asterisk","Postman","Windows Server 2012","SOA","MobX","Smarty","Flex","Flow","VUE.js","Coffeecup HTML Editor","reactJS","vue js","RxJs","Rest API","DOM","MS Movie Maker","Apollo","Hooks","Next.js","NPM","Zappier","Product Promotion","Арабский язык","Customer Relationship Management","Start-up project","Product Marketing","Product Manager","Mobile Marketing","A/B тесты","Умение структурировать информацию","Умение обучать других","Быстрая адаптация и обучение","Проактивность","test plan","test cases","Rust","Консультирование клиентов по телефону","Ответственное хранение","1С: Производство","Social media","Live Streaming","Short Video","Communication Skill","Key Account Management","Organization Skills","Lean Production","Управление поставками","Продюсирование"]
wiki_lst=[]
title=[]
i = 0
for article in articles:
   i = i + 1
   print(f"loading ({i} of {len(articles)}) content: {article}")
   page = None
   try:
        page = wikipedia.page(article, redirect=True, preload=True)
        wiki_lst.append(page.content)
        title.append(article)
   except:
       print('Fail to load page')
print("examine content")
# Out:
# loading (1 of 1092) content: JavaScript
# loading (2 of 1092) content: PHP
# Fail to load page
# loading (3 of 1092) content: MySQL
# loading (4 of 1092) content: PostgreSQL
# loading (5 of 1092) content: Linux
# Fail to load page
# loading (6 of 1092) content: SQL
# Fail to load page
# loading (7 of 1092) content: ООП
# loading (8 of 1092) content: HTML
# loading (9 of 1092) content: CSS
# Fail to load page
# loading (10 of 1092) content: Java
# loading (11 of 1092) content: Python
# Fail to load page
# loading (12 of 1092) content: Node.js
# Fail to load page
# loading (13 of 1092) content: HTML5
# loading (14 of 1092) content: jQuery
# loading (15 of 1092) content: CSS3
# loading (16 of 1092) content: C#
# loading (17 of 1092) content: MongoDB
# loading (18 of 1092) content: REST
# Fail to load page
# loading (19 of 1092) content: Redis
# loading (20 of 1092) content: React
# Fail to load page
# loading (21 of 1092) content: Spring Framework
# loading (22 of 1092) content: Docker
# ...

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
vectorizer = TfidfVectorizer(stop_words={'english'})
X = vectorizer.fit_transform(wiki_lst)

# %%
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans
Sum_of_squared_distances = []
K = range(2,10)
for k in K:
   km = KMeans(n_clusters=k, max_iter=200, n_init=10)
   km = km.fit(X)
   Sum_of_squared_distances.append(km.inertia_)
plt.plot(K, Sum_of_squared_distances, 'bx-')
plt.xlabel('k')
plt.ylabel('Sum_of_squared_distances')
plt.title('Elbow Method For Optimal k')
plt.show()

# %%
true_k = 6
model = KMeans(n_clusters=true_k, init='k-means++', max_iter=200, n_init=10)
model.fit(X)
labels=model.labels_
wiki_cl=pd.DataFrame(list(zip(title,labels)),columns=['title','cluster'])
print(wiki_cl.sort_values(by=['cluster']))
# Out:
#                     title  cluster
# 204                Vue js        0
# 91                 vue.js        0
# 570                VUE.js        0
# 507                Vue.JS        0
# 49                 Vue.js        0
# ..                    ...      ...
# 267   Presentation skills        5
# 266               Eclipse        5
# 265              Helpdesk        5
# 262  Business Development        5
# 593       Lean Production        5
#
# [594 rows x 2 columns]

# %%
from wordcloud import WordCloud
result={'cluster':labels,'wiki':wiki_lst}
result=pd.DataFrame(result)
for k in range(0,true_k):
   s=result[result.cluster==k]
   text=s['wiki'].str.cat(sep=' ')
   text=text.lower()
   text=' '.join([word for word in text.split()])
   wordcloud = WordCloud(max_font_size=50, max_words=100, background_color="white").generate(text)
   print('Cluster: {}'.format(k))
   print('Titles')
   titles=wiki_cl[wiki_cl.cluster==k]['title']
   print(titles.to_string(index=False))
   plt.figure()
   plt.imshow(wordcloud, interpolation="bilinear")
   plt.axis("off")
   plt.show()
# Out:
# Cluster: 0
# Titles
#                          Vue.js
#                          vue.js
#                          Vue JS
#                          Vue js
#  • JS / TypeScript / HTML / CSS
#                          Vue.JS
#                          VUE.JS
#                          VUE.js
#                          vue js
# Cluster: 1
# Titles
#               Английский язык
#      Agile Project Management
#                      JSON API
#                       Java EE
#           Управление командой
#                          Gulp
#                         JUnit
#                          Bash
#                         Figma
#                 Бизнес-анализ
#                         CI/CD
#                       Magento
#                        Elixir
#           Управление временем
#                         SOLID
#                           WCF
#                  Selenium IDE
#                     Аналитика
#                        Celery
#                       EVO CMS
# ...

# %%
import json

fileName = f"./wiki_articles.json"
f = open(fileName, mode='w', encoding='utf8')
f.write(json.dumps({
    'articles': articles,
    'wiki_lst': wiki_lst,
    'title': title,
}, ensure_ascii=False))
f.close()
